# %%
import pandas as pd

# %%
df = pd.read_csv('./electricity.csv', index_col='turned_on')

# %%
df.index[0]
# Out:
# '2021-01-13 19:49:27'

# %%
import datetime
dt_string = df.index[0]
format = "%Y-%m-%d %H:%M:%S"
dt_object = datetime.datetime.strptime(dt_string, format)

# %%
int(dt_object.timestamp() * 1000)
# Out:
# 1610547567000

# %%
import boto3
from boto3.dynamodb.conditions import Key, Attr

# %%
db = boto3.resource(
    service_name= "dynamodb",
    region_name= "ap-south-1",
    aws_access_key_id= "AKIAU5AT5CQR67O3F6AL",
    aws_secret_access_key= "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"
)

# %%
table = db.Table('Electricity')

# %%
items = table.scan()['Items']

# %%
d1 = items[0]

# %%
t = d1['turned_on']
t
# Out:
# Decimal('1647029622')

# %%
datetime.datetime.fromtimestamp(int(t))
# Out:
# datetime.datetime(2022, 3, 12, 1, 43, 42)

# %%
len(table.scan(
    FilterExpression = Key('turned_on').between(1656750270, 1657299616)
)['Items'])
# Out:
# 16

# %%
table.scan(
    FilterExpression="between (#voltage, :base, :end)",
    ExpressionAttributeNames={
        '#voltage': 'voltage'
    },
    ExpressionAttributeValues={
        ':base':170,
        ':end':180
    }
)['Items']
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# Input In [110], in <cell line: 1>()
# ----> 1 table.scan(
#       2     FilterExpression="between (#voltage, :base, :end)",
#       3     ExpressionAttributeNames={
#       4         '#voltage': 'voltage'
#       5     },
#       6     ExpressionAttributeValues={
#       7         ':base':170,
#       8         ':end':180
#       9     }
#      10 )['Items']
#
# File c:\python39\lib\site-packages\boto3\resources\factory.py:580, in ResourceFactory._create_action.<locals>.do_action(self, *args, **kwargs)
#     579 def do_action(self, *args, **kwargs):
# --> 580     response = action(self, *args, **kwargs)
#     582     if hasattr(self, 'load'):
#     583         # Clear cached data. It will be reloaded the next
#     584         # time that an attribute is accessed.
#     585         # TODO: Make this configurable in the future?
# ...

# %%
import requests
import json
data = {
    "turned_on": {
        "operation": "gte",
        "value": 1656750270
    }, 
    "turned_on": {
        "operation": "lte",
        "value": 1657299616
    }
}
data = json.dumps(data)
data
# Out:
# '{"turned_on": {"operation": "lte", "value": 1657299616}}'

# %%
res=requests.post('https://snieah51ma.execute-api.ap-south-1.amazonaws.com/v1/readings', data = {
    'turned_on': {
        'operation': 'gte',
        'value': 1656750270
    }
})

# %%
import requests

data = {
    "7": {
        "key": "turned_on",
        "operation": "gte",
        "value": 1609490557  
      },
}

payload = {
       
      "1": {
        "key": "voltage",
        "operation": "gte",
        "value": 0
      },
      "2": {
        "key": "voltage",
        "operation": "lte",
        "value": 240
      },
      "3": {
        "key": "current",
        "operation": "gte",
        "value": 0
      },
      "4": {
        "key": "current",
        "operation": "lte",
        "value": 10
      },
      "5": {
        "key": "power",
        "operation": "gte",
        "value": 0
      },
      "6": {
        "key": "power",
        "operation": "lte",
        "value": 500
      },
    }
        

res = requests.post('https://snieah51ma.execute-api.ap-south-1.amazonaws.com/v1/readings', data=json.dumps(data))
print(res.text)
# Out:
# [
#     {
#         "current": 7.21,
#         "power": 1497.08,
#         "voltage": 207.64,
#         "span": 65101.0,
#         "turned_on": 1647029622.0
#     },
#     {
#         "current": 1.51,
#         "power": 116.53,
#         "voltage": 77.17,
#         "span": 25922.0,
#         "turned_on": 1621665331.0
#     },
#     {
#         "current": 0.49,
#         "power": 90.71,
#         "voltage": 185.12,
#         "span": 29103.0,
#         "turned_on": 1653601615.0
#     },
#     {
#         "current": 6.41,
#         "power": 534.47,
#         "voltage": 83.38,
#         "span": 24420.0,
#         "turned_on": 1648405971.0
#     },
#     {
#         "current": 8.93,
#         "power": 306.92,
#         "voltage": 34.37,
#         "span": 5045.0,
#         "turned_on": 1625453873.0
#     },
#     {
#         "current": 7.59,
#         "power": 856.46,
#         "voltage": 112.84,
#         "span": 3.0,
#         "turned_on": 1658546993.0
#     },
#     {
# ...

# %%
len(table.scan(
    FilterExpression=Key('turned_on').lte(1657299616)
)['Items'])
# Out:
# 932

# %%
print(payload)
# Out:
# {"voltage": {"operation": "gte", "value": 170}}
